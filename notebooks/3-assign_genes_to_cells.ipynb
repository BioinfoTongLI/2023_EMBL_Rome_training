# %%
from bin.label_to_shapely import get_shapely
from bin.str_indexing import get_STRtree_per_channel
from bin.assign import assign
import tifffile as tf
import pandas as pd
from bin.count_table_2_h5ad import to_h5ad

# %%
root = "/lustre/scratch126/cellgen/team283/tl10/EMBL_training/training/assign/"

# %%
lab_img = tf.imread(f"{root}/in/cellpose_segmentation.tif")
decoded = pd.read_csv(f"{root}/in/EMBL_training_mouse_brain_decoded_df.tsv", sep="\t")

# %%
decoded
# Out:
#              name    code  probability  y_int  x_int  index_code  axis  r0_c0  \
# 3         Slc17a7  TTTACA     0.925702      2   2861    333414.0     1     19
# 5          Slc6a3  TGAACC     0.921824      1   3598    324411.0     1      0
# 8      background    0000     0.962358      2    473         NaN     1      0
# 9         Neurod1  ATCCGA     0.915770      2    980    431124.0     1     23
# 19           Chat  CATAGG     0.951215      4    757    143422.0     1      3
# ...           ...     ...          ...    ...    ...         ...   ...    ...
# 19563  background    0000     0.962358   4110    554         NaN     1      0
# 19564  background    0000     0.962358   4110   1043         NaN     1      0
# 19565  background    0000     0.962358   4110   1162         NaN     1      0
# 19566  background    0000     0.962358   4110   1788         NaN     1      0
# 19567  background    0000     0.962358   4111   3455         NaN     1      0
#
# ...

# %%
lab_shapely, _ = get_shapely(lab_img)

# %%
lab_shapely
# Out:
# {1: <MULTIPOLYGON (((58 0, 58 2, 57 3, 57 38, 58 39, 58 42, 59 43, 59 46, 60 47,...>,
#  2: <MULTIPOLYGON (((720 0, 720 2, 719 3, 720 4, 720 7, 721 8, 721 9, 722 10, 72...>,
#  3: <MULTIPOLYGON (((862 0, 862 2, 861 3, 861 6, 862 7, 862 10, 863 11, 863 12, ...>,
#  4: <MULTIPOLYGON (((928 0, 927 1, 927 2, 926 3, 926 4, 925 5, 925 6, 924 7, 924...>,
#  5: <MULTIPOLYGON (((2483 0, 2483 1, 2482 2, 2482 5, 2481 6, 2481 12, 2482 13, 2...>,
#  6: <MULTIPOLYGON (((2980 0, 2980 1, 2979 2, 2979 4, 2980 5, 2980 8, 2981 9, 298...>,
#  7: <MULTIPOLYGON (((3031 0, 3031 5, 3032 6, 3032 8, 3033 9, 3033 12, 3034 13, 3...>,
#  8: <MULTIPOLYGON (((3103 0, 3103 4, 3102 5, 3102 10, 3101 11, 3101 18, 3103 20,...>,
#  9: <MULTIPOLYGON (((3438 0, 3438 1, 3437 2, 3437 3, 3436 4, 3436 5, 3435 6, 343...>,
#  10: <MULTIPOLYGON (((3495 0, 3495 5, 3496 6, 3496 8, 3497 9, 3497 10, 3498 11, 3...>,
#  11: <MULTIPOLYGON (((3647 0, 3646 1, 3646 3, 3645 4, 3645 7, 3644 8, 3644 15, 36...>,
# ...

# %%
decoded = decoded[decoded.Probability > 0.9]

# %%
str_trees = get_STRtree_per_channel(decoded, ch_col_name="name",x_col="x_int", y_col="y_int")

# %%
str_trees
# Out:
# {'Ache': <shapely.strtree.STRtree at 0x7ff2578cd8b0>,
#  'Acta2': <shapely.strtree.STRtree at 0x7ff2578cd970>,
#  'Aldoc': <shapely.strtree.STRtree at 0x7ff2578cdd00>,
#  'Bdnf': <shapely.strtree.STRtree at 0x7ff2578cdd90>,
#  'Calca': <shapely.strtree.STRtree at 0x7ff2578cde20>,
#  'Chat': <shapely.strtree.STRtree at 0x7ff2578cdeb0>,
#  'Fos': <shapely.strtree.STRtree at 0x7ff2578cdf70>,
#  'Gad1': <shapely.strtree.STRtree at 0x7ff2578cddc0>,
#  'Gad2': <shapely.strtree.STRtree at 0x7ff2578cdb20>,
#  'Gfap': <shapely.strtree.STRtree at 0x7ff2578cdc70>,
#  'Gja1': <shapely.strtree.STRtree at 0x7ff2578cdf10>,
#  'Laptm5': <shapely.strtree.STRtree at 0x7ff2578cd9a0>,
#  'Mbp': <shapely.strtree.STRtree at 0x7ff2578cdee0>,
#  'Ndnf': <shapely.strtree.STRtree at 0x7ff2578cda90>,
#  'Neurod1': <shapely.strtree.STRtree at 0x7ff257868430>,
#  'Npy': <shapely.strtree.STRtree at 0x7ff2578684c0>,
#  'Npy2r': <shapely.strtree.STRtree at 0x7ff257868550>,
# ...

# %%
lab_shapely
# Out:
# {1: <MULTIPOLYGON (((58 0, 58 2, 57 3, 57 38, 58 39, 58 42, 59 43, 59 46, 60 47,...>,
#  2: <MULTIPOLYGON (((720 0, 720 2, 719 3, 720 4, 720 7, 721 8, 721 9, 722 10, 72...>,
#  3: <MULTIPOLYGON (((862 0, 862 2, 861 3, 861 6, 862 7, 862 10, 863 11, 863 12, ...>,
#  4: <MULTIPOLYGON (((928 0, 927 1, 927 2, 926 3, 926 4, 925 5, 925 6, 924 7, 924...>,
#  5: <MULTIPOLYGON (((2483 0, 2483 1, 2482 2, 2482 5, 2481 6, 2481 12, 2482 13, 2...>,
#  6: <MULTIPOLYGON (((2980 0, 2980 1, 2979 2, 2979 4, 2980 5, 2980 8, 2981 9, 298...>,
#  7: <MULTIPOLYGON (((3031 0, 3031 5, 3032 6, 3032 8, 3033 9, 3033 12, 3034 13, 3...>,
#  8: <MULTIPOLYGON (((3103 0, 3103 4, 3102 5, 3102 10, 3101 11, 3101 18, 3103 20,...>,
#  9: <MULTIPOLYGON (((3438 0, 3438 1, 3437 2, 3437 3, 3436 4, 3436 5, 3435 6, 343...>,
#  10: <MULTIPOLYGON (((3495 0, 3495 5, 3496 6, 3496 8, 3497 9, 3497 10, 3498 11, 3...>,
#  11: <MULTIPOLYGON (((3647 0, 3646 1, 3646 3, 3645 4, 3645 7, 3644 8, 3644 15, 36...>,
# ...

# %%
assign(str_trees, lab_shapely, stem=f"{root}/out/demo_optflow_seg_optflow_reg_result_stack_detected_peaks_diam_5_percentile_90_sep_3_search_range_5_decoded_df_prob_thresholded_0.9")

# %%
! ls "{root}/out/"
# Out:
# EMBL_training.h5ad
# EMBL_training_n_gene_min_4.h5ad
# demo_optflow_seg_optflow_reg_result_stack_detected_peaks_diam_5_percentile_90_sep_3_search_range_5_decoded_df_prob_thresholded_0.9_assigned_peaks.csv
# demo_optflow_seg_optflow_reg_result_stack_detected_peaks_diam_5_percentile_90_sep_3_search_range_5_decoded_df_prob_thresholded_0.9_cell_centroids.csv
# demo_optflow_seg_optflow_reg_result_stack_detected_peaks_diam_5_percentile_90_sep_3_search_range_5_decoded_df_prob_thresholded_0.9_peak_counts.csv

# %%
to_h5ad(f"{root}/out/demo_optflow_seg_optflow_reg_result_stack_detected_peaks_diam_5_percentile_90_sep_3_search_range_5_decoded_df_prob_thresholded_0.9_peak_counts.csv",
        f"{root}/out/demo_optflow_seg_optflow_reg_result_stack_detected_peaks_diam_5_percentile_90_sep_3_search_range_5_decoded_df_prob_thresholded_0.9_cell_centroids.csv",
        f"{root}/out/EMBL_training")
# Out:
# /opt/conda/envs/EMBL_training/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /lustre/scratch126/cellgen/team283/tl10/2023_EMBL_Rome_training/notebooks/bin/count_table_2_h5ad.py:38: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['total_counts'] = adata.X.sum(0)
# /opt/conda/envs/EMBL_training/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /opt/conda/envs/EMBL_training/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
! ls "{root}/out/"
# Out:
# EMBL_training.h5ad
# EMBL_training_n_gene_min_4.h5ad
# demo_optflow_seg_optflow_reg_result_stack_detected_peaks_diam_5_percentile_90_sep_3_search_range_5_decoded_df_prob_thresholded_0.9_assigned_peaks.csv
# demo_optflow_seg_optflow_reg_result_stack_detected_peaks_diam_5_percentile_90_sep_3_search_range_5_decoded_df_prob_thresholded_0.9_cell_centroids.csv
# demo_optflow_seg_optflow_reg_result_stack_detected_peaks_diam_5_percentile_90_sep_3_search_range_5_decoded_df_prob_thresholded_0.9_peak_counts.csv

# %%
import anndata as ad

# %%
adata = ad.read_h5ad(f"{root}/out/EMBL_training.h5ad")
adata
# Out:
# /opt/conda/envs/EMBL_training/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# AnnData object with n_obs × n_vars = 0 × 34
#     obs: 'sample', 'total_counts', 'n_genes_by_counts'
#     var: 'total_counts', 'n_cells_by_counts'
#     obsm: 'spatial'

# %%
adata.obs
# Out:
# Empty DataFrame
# Columns: [sample, total_counts, n_genes_by_counts]
# Index: []
